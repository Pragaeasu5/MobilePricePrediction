# %%
import pandas as pd
import numpy as np

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('/content/mobile_price_train.csv')

# %%
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         21       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
df.tail()
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# 1995    0.8        106        6  ...       1222      1890   668    13     4
# 1996    0.2        187        4  ...        915      1965  2032    11    10
# 1997    0.7        108        8  ...        868      1632  3057     9     1
# 1998    0.1        145        5  ...        336       670   869    18    10
# 1999    0.9        168        6  ...        483       754  3919    19     4
#
#       talk_time  three_g  touch_screen  wifi  price_range
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
df.shape
# Out:
# (2000, 21)

# %% [markdown]
# #ploting relation between price range & Battery power

# %%
plt.figure(figsize = (12,6))
sns.barplot(x = 'price_range', y = 'battery_power', data=df)
plt.show()

# %% [markdown]
# #Plotting Relation between Price Range & Pixel Height/width

# %%
plt.figure(figsize = (14,6))
plt.subplot(1,2,1)
sns.barplot(x = 'price_range', y = 'px_height', data=df,palette = 'Reds')
plt.subplot(1,2,2)
sns.barplot(x = 'price_range', y = 'px_height', data=df,palette = 'Blues')
plt.show()
# Out:
# <ipython-input-11-50fec9a1ca63>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = 'price_range', y = 'px_height', data=df,palette = 'Reds')
# <ipython-input-11-50fec9a1ca63>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = 'price_range', y = 'px_height', data=df,palette = 'Blues')

# %% [markdown]
# #Plotting Relation between Price Range & RAM

# %%
plt.figure(figsize = (12,6))
sns.barplot(x = 'price_range',y = 'ram',data=df)
plt.show()

# %% [markdown]
# #Plotting Relation between Price Range &3G/4G

# %%
plt.figure(figsize = (12,6))
sns.barplot(x = 'price_range',y = 'four_g',data=df)
plt.show()

# %% [markdown]
# #Plotting Relation between Price Range & Memory

# %%
plt.figure(figsize = (12,6))
sns.lineplot(x = 'price_range'  , y = 'int_memory' , data=df,hue = 'dual_sim')
plt.show()

# %% [markdown]
# #Data Preprocessing

# %%
x = df.drop(['price_range'] , axis = 1)
y = df['price_range']

# %%
x
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
y
# Out:
# 0       1
# 1       2
# 2       2
# 3       2
# 4       1
#        ..
# 1995    0
# 1996    2
# 1997    3
# 1998    0
# 1999    3
# Name: price_range, Length: 2000, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.25)

# %% [markdown]
# #Algorithm Decision

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
import pickle as pkl

# %%
import joblib

# %%
joblib.dump(lr,'/content/Mobile-data-train.pkl')
# Out:
# ['/content/Mobile-data-train.pkl']

# %% [markdown]
# #Test the Logic

# %%
ypred =lr.predict(x_test)

# %% [markdown]
# #Evaluation Metrics

# %%
from sklearn.metrics import r2_score,mean_squared_error

# %% [markdown]
# Regression

# %%
r2_score(y_test,ypred)
# Out:
# 0.9093364377032881

# %%
mean_squared_error(y_test,ypred)
# Out:
# 0.11079087312658197

# %%
rmse = (np.sqrt(mean_squared_error(y_test,ypred)))
rmse
# Out:
# 0.3328526297426264

# %% [markdown]
# #KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=10)
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=10)

# %%
knn.score(x_train, y_train)
# Out:
# 0.944

# %%
predictions = knn.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test , predictions)
# Out:
# 0.924

# %% [markdown]
# #Predicting Values for test.csv

# %%
test_df = pd.read_csv('/content/Mobile-data-test.csv')

# %%
test_df.head()
# Out:
#    id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0   1           1043     1          1.8         1  14       0           5
# 1   2            841     1          0.5         1   4       1          61
# 2   3           1807     1          2.8         0   1       0          27
# 3   4           1546     0          0.5         1  18       1          25
# 4   5           1434     0          1.4         0  11       1          49
#
#    m_dep  mobile_wt  ...  pc  px_height  px_width   ram  sc_h  sc_w  \
# 0    0.1        193  ...  16        226      1412  3476    12     7
# 1    0.8        191  ...  12        746       857  3895     6     0
# 2    0.9        186  ...   4       1270      1366  2396    17    10
# 3    0.5         96  ...  20        295      1752  3893    10     0
# 4    0.5        108  ...  18        749       810  1773    15     8
#
#    talk_time  three_g  touch_screen  wifi
# 0          2        0             1     0
# ...

# %%
test_df.shape
# Out:
# (2000, 21)

# %%
test_df = test_df.drop(['blue'], axis = 1)
test_df.shape
# Out:
# (2000, 20)

# %%
test_df = test_df.drop(['id'], axis = 1)
test_df.shape
# Out:
# (1000, 20)

# %%
test_df = test_df.drop(['clock_speed'], axis = 1)
test_df.shape
# Out:
# (1000, 19)

# %%
test_df = test_df.drop(['touch_screen','n_cores'], axis = 1)
test_df.shape
# Out:
# (1000, 17)

# %%
test_df = test_df.drop(['m_dep'], axis = 1)
test_df.shape
# Out:
# (1000, 16)

# %%
test_df.head()
# Out:
#    battery_power  blue  dual_sim  fc  four_g  int_memory  mobile_wt  pc  \
# 0           1043     1         1  14       0           5        193  16
# 1            841     1         1   4       1          61        191  12
# 2           1807     1         0   1       0          27        186   4
# 3           1546     0         1  18       1          25         96  20
# 4           1434     0         0  11       1          49        108  18
#
#    px_height  px_width   ram  sc_h  sc_w  talk_time  three_g  wifi
# 0        226      1412  3476    12     7          2        0     0
# 1        746       857  3895     6     0          7        1     0
# 2       1270      1366  2396    17    10         10        0     1
# 3        295      1752  3893    10     0          7        1     0
# 4        749       810  1773    15     8          7        1     1

# %%
test_df = test_df.drop(['blue'], axis = 1)
test_df.shape
# Out:
# (1000, 15)

# %%
test_df.head()
# Out:
#    battery_power  dual_sim  fc  four_g  int_memory  mobile_wt  pc  px_height  \
# 0           1043         1  14       0           5        193  16        226
# 1            841         1   4       1          61        191  12        746
# 2           1807         0   1       0          27        186   4       1270
# 3           1546         1  18       1          25         96  20        295
# 4           1434         0  11       1          49        108  18        749
#
#    px_width   ram  sc_h  sc_w  talk_time  three_g  wifi
# 0      1412  3476    12     7          2        0     0
# 1       857  3895     6     0          7        1     0
# 2      1366  2396    17    10         10        0     1
# 3      1752  3893    10     0          7        1     0
# 4       810  1773    15     8          7        1     1

# %%
import pickle as pkl

# %%
pkl.dump(lr,open('/content/Mobile-data-train.csv','wb'))

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd


id=float(input('Enter a id number: '))
battery_power=float(input('Enter battery_power:'))
blue=float(input('Enter a color : '))
clock_speed=float(input('Enter a clock_speed: '))
dual_sim=float(input('Enter dual_sim: '))
fc=float(input('Enter fc: '))
four_g=float(input('Enter four_g: '))
int_memory = float(input('Enter memory: '))
m_dep=float(input('Enter a M_dep: '))
mobile_wt=float(input('Enter a moblie width : '))
n_cores=float(input('Enter a n_cores: '))
pc=float(input('Enter pc: '))
px_height=(input('Enter px_height: '))
px_width=(input('Enter px_width: '))
ram=float(input('Enter RAM: '))
sc_h=float(input('Enter sc_h: '))
sc_w=float(input('Enter sc_w: '))
talk_time=float(input('Enter talk_time: '))
three_g=float(input('Enter three_g: '))
touch_screen=float(input('Enter a tough_screen: '))
wifi=float(input('Enter wifi: '))


test_df = pd.DataFrame({
    'battery_power': [battery_power],
    'blue': [blue],
    'clock_speed': [clock_speed],
    'dual_sim': [dual_sim],
    'fc': [fc],
    'four_g': [four_g],
    'int_memory': [int_memory],
    'm_dep': [m_dep],
    'mobile_wt': [mobile_wt],
    'n_cores': [n_cores],
    'pc': [pc],
    'px_height': [px_height],
    'px_width': [px_width],
    'ram': [ram],
    'sc_h': [sc_h],
    'sc_w': [sc_w],
    'talk_time': [talk_time],
    'three_g': [three_g],
    'touch_screen': [touch_screen],
    'wifi': [wifi]
})


test_df = pd.read_csv('/content/Mobile-data-test.csv')


test_df = test_df.drop(columns=['id'])

test_features = test_df[['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
                         'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
                         'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
                         'touch_screen', 'wifi']]





test_pred = knn.predict(test_features)

predicted_price_range = pd.Series(test_pred).mode()[0]

print('Predicted price_range:', predicted_price_range)
